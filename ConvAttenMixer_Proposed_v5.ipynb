# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/ConvAttenMixer/blob/main/ConvAttenMixer_Proposed_v5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MRI Brain Tumor Classification
# # Proposed Method V5
# Data Augmnetation
# Update in the classification head

# %%
# !pip install -U tensorflow-addons
# !pip install --upgrade accelerate
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.21.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.optimizers import Adam

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
from google.colab import drive
import tensorflow_addons as tfa

# %% [markdown]
# # Prepare the data

# %%
BATCH_SIZE = 64
IMG_SIZE = (224, 224)
NUM_CLASSES = 4
input_shape = (224, 224, 3)

drive.mount('/content/drive', force_remount=True)
# train data
train_ds = image_dataset_from_directory(
    directory='/content/drive/MyDrive/Brain Tumor MRI/data/Training/',
    #directory='Brain Tumor MRI/data/Training/',
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    shuffle=True,
    seed=1024,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)

# validation data
val_ds = image_dataset_from_directory(
    directory='/content/drive/MyDrive/Brain Tumor MRI/data/Testing/',
    #directory='Brain Tumor MRI/data/Testing/',
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    shuffle=True,
    seed=1024,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Mounted at /content/drive
# Found 5712 files belonging to 4 classes.
# Found 1311 files belonging to 4 classes.

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])
#Rescale pixel values
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %%
for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# # Hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
label_smoothing = 0.1

filters=256
depth=8
kernel_size=5
num_epochs = 30
patch_size = 4  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 32
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2

#num_transformer_blocks = 8  # Number of repetitions of the transformer layer
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
# Out:
# Patch size: 4 X 4 = 16
# Patches per image: 3136

# %% [markdown]
# # Patch extraction and embedding : encoding layer

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))

class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %% [markdown]
# # External attention block

# %%
def external_attention(x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %% [markdown]
# # Implement Conv.1D block

# %%
class SqueezeExcite(layers.Layer):
    """Applies squeeze and excitation to input feature maps as seen in https://arxiv.org/abs/1709.01507.
    Args:
        ratio: The ratio with which the feature map needs to be reduced in the reduction phase.
    Inputs:
        Convolutional features.
    Outputs:
        Attention modified feature maps.
    """
    def __init__(self, ratio, **kwargs):
        super().__init__(**kwargs)
        self.ratio = ratio

    def get_config(self):
        config = super().get_config()
        config.update({"ratio": self.ratio})
        return config

    def build(self, input_shape):
        filters = input_shape[-1]
        self.squeeze = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = layers.Dense(
            units=filters // self.ratio, activation="relu", use_bias=False,
        )
        self.excite = layers.Dense(units=filters, activation="sigmoid", use_bias=False)
        self.multiply = layers.Multiply()

    def call(self, x):
        shortcut = x
        x = self.squeeze(x)
        x = self.reduction(x)
        x = self.excite(x)
        x = self.multiply([shortcut, x])
        return x

def conv1d(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Conv1D(mlp_dim,2, padding="same")(x)
    #x = layers.Conv1D(embedding_dim, 2, padding="same")(x)
    SqueezeExcite(x)
    x = layers.Conv1D(embedding_dim, 3, padding="same")(x)
    return x

# %% [markdown]
# # ConvMixer utilities

# %% [markdown]
# The model used in this experiment is termed as ConvMixer-256/8 where 256 denotes the number of channels and 8 denotes the depth. The resulting model only has 0.8 million parameters.

# %%
def activation_block(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = layers.Conv1D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_block(x)

def conv_mixer_block(x, filters: int, kernel_size: int):
    # Depthwise convolution.
    x0 = x
    x = layers.DepthwiseConv1D(kernel_size=kernel_size, padding="same")(x)
    x = layers.Add()([activation_block(x), x0])  # Residual.
    # Pointwise convolution.
    x = layers.Conv1D(filters, kernel_size=1)(x)
    x = activation_block(x)
    return x

def get_conv_mixer_256_8(x):
    """ConvMixer-256/8: https://openreview.net/pdf?id=TVHS5Y4dNvM.
    The hyperparameter values are taken from the paper.
    """
    x = layers.Rescaling(scale=1.0 / 255)(x)
    # Extract patch embeddings.
    x = conv_stem(x, filters, patch_size)
    # ConvMixer blocks.
    for _ in range(depth):
        x = conv_mixer_block(x, filters, kernel_size)
    return x

# %% [markdown]
# # Proposed combined (ConvMixer, SA, EA) model

# %%
def get_model():
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)

    ################## STEP 1 : Patch Embedding ##################
    # Extract patches
    x = PatchExtract(patch_size)(x)
    # Create patch embedding
    x = PatchEmbedding(num_patches, embedding_dim)(x)

    ################## STEP 2 : ConvMixer      ##################
    x = get_conv_mixer_256_8(x)

    ################## STEP 3 : Self-attention ##################
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])

     ################## STEP 4 : ConvMixer      ##################
    x = get_conv_mixer_256_8(x)

    ################## STEP 5 : External attention ##################
    x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)

    # Classification block
    x = conv1d(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    x = layers.GlobalAvgPool1D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  patch_extract (PatchExtract)   (None, 3136, 48)     0           ['sequential[0][0]']
#
#  patch_embedding (PatchEmbeddin  (None, 3136, 64)    203840      ['patch_extract[0][0]']
#  g)
#
#  rescaling_1 (Rescaling)        (None, 3136, 64)     0           ['patch_embedding[0][0]']
#
#  conv1d (Conv1D)                (None, 784, 256)     65792       ['rescaling_1[0][0]']
#
#  activation (Activation)        (None, 784, 256)     0           ['conv1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 784, 256)    1024        ['activation[0][0]']
#  alization)
#
#  depthwise_conv1d (DepthwiseCon  (None, 784, 256)    1536        ['batch_normalization[0][0]']
#  v1D)
#
#  activation_1 (Activation)      (None, 784, 256)     0           ['depthwise_conv1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 784, 256)    1024        ['activation_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 784, 256)     0           ['batch_normalization_1[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 784, 256)     65792       ['add[0][0]']
#
#  activation_2 (Activation)      (None, 784, 256)     0           ['conv1d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 784, 256)    1024        ['activation_2[0][0]']
#  rmalization)
#
#  depthwise_conv1d_1 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_2[0][0]']
#  onv1D)
#
#  activation_3 (Activation)      (None, 784, 256)     0           ['depthwise_conv1d_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 784, 256)    1024        ['activation_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 784, 256)     0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 784, 256)     65792       ['add_1[0][0]']
#
#  activation_4 (Activation)      (None, 784, 256)     0           ['conv1d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 784, 256)    1024        ['activation_4[0][0]']
#  rmalization)
#
#  depthwise_conv1d_2 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_4[0][0]']
#  onv1D)
#
#  activation_5 (Activation)      (None, 784, 256)     0           ['depthwise_conv1d_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 784, 256)    1024        ['activation_5[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 784, 256)     0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 784, 256)     65792       ['add_2[0][0]']
#
#  activation_6 (Activation)      (None, 784, 256)     0           ['conv1d_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 784, 256)    1024        ['activation_6[0][0]']
#  rmalization)
#
#  depthwise_conv1d_3 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_6[0][0]']
#  onv1D)
#
#  activation_7 (Activation)      (None, 784, 256)     0           ['depthwise_conv1d_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 784, 256)    1024        ['activation_7[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 784, 256)     0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 784, 256)     65792       ['add_3[0][0]']
#
#  activation_8 (Activation)      (None, 784, 256)     0           ['conv1d_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 784, 256)    1024        ['activation_8[0][0]']
#  rmalization)
#
#  depthwise_conv1d_4 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_8[0][0]']
#  onv1D)
#
#  activation_9 (Activation)      (None, 784, 256)     0           ['depthwise_conv1d_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 784, 256)    1024        ['activation_9[0][0]']
#  rmalization)
#
#  add_4 (Add)                    (None, 784, 256)     0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 784, 256)     65792       ['add_4[0][0]']
#
#  activation_10 (Activation)     (None, 784, 256)     0           ['conv1d_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 784, 256)    1024        ['activation_10[0][0]']
#  ormalization)
#
#  depthwise_conv1d_5 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_10[0][0]']
#  onv1D)
#
#  activation_11 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_5[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 784, 256)    1024        ['activation_11[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 784, 256)     0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 784, 256)     65792       ['add_5[0][0]']
#
#  activation_12 (Activation)     (None, 784, 256)     0           ['conv1d_6[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 784, 256)    1024        ['activation_12[0][0]']
#  ormalization)
#
#  depthwise_conv1d_6 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_12[0][0]']
#  onv1D)
#
#  activation_13 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_6[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 784, 256)    1024        ['activation_13[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 784, 256)     0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 784, 256)     65792       ['add_6[0][0]']
#
#  activation_14 (Activation)     (None, 784, 256)     0           ['conv1d_7[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 784, 256)    1024        ['activation_14[0][0]']
#  ormalization)
#
#  depthwise_conv1d_7 (DepthwiseC  (None, 784, 256)    1536        ['batch_normalization_14[0][0]']
#  onv1D)
#
#  activation_15 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_7[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 784, 256)    1024        ['activation_15[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 784, 256)     0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 784, 256)     65792       ['add_7[0][0]']
#
#  activation_16 (Activation)     (None, 784, 256)     0           ['conv1d_8[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 784, 256)    1024        ['activation_16[0][0]']
#  ormalization)
#
#  layer_normalization (LayerNorm  (None, 784, 256)    512         ['batch_normalization_16[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 784, 256)    263168      ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add_8 (Add)                    (None, 784, 256)     0           ['multi_head_attention[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  rescaling_2 (Rescaling)        (None, 784, 256)     0           ['add_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 196, 256)     262400      ['rescaling_2[0][0]']
#
#  activation_17 (Activation)     (None, 196, 256)     0           ['conv1d_9[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 196, 256)    1024        ['activation_17[0][0]']
#  ormalization)
#
#  depthwise_conv1d_8 (DepthwiseC  (None, 196, 256)    1536        ['batch_normalization_17[0][0]']
#  onv1D)
#
#  activation_18 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_8[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 196, 256)    1024        ['activation_18[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 196, 256)     0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 196, 256)     65792       ['add_9[0][0]']
#
#  activation_19 (Activation)     (None, 196, 256)     0           ['conv1d_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 196, 256)    1024        ['activation_19[0][0]']
#  ormalization)
#
#  depthwise_conv1d_9 (DepthwiseC  (None, 196, 256)    1536        ['batch_normalization_19[0][0]']
#  onv1D)
#
#  activation_20 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_9[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 196, 256)    1024        ['activation_20[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 196, 256)     0           ['batch_normalization_20[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 196, 256)     65792       ['add_10[0][0]']
#
#  activation_21 (Activation)     (None, 196, 256)     0           ['conv1d_11[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 196, 256)    1024        ['activation_21[0][0]']
#  ormalization)
#
#  depthwise_conv1d_10 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_21[0][0]']
#  Conv1D)
#
#  activation_22 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_10[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 196, 256)    1024        ['activation_22[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 196, 256)     0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 196, 256)     65792       ['add_11[0][0]']
#
#  activation_23 (Activation)     (None, 196, 256)     0           ['conv1d_12[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 196, 256)    1024        ['activation_23[0][0]']
#  ormalization)
#
#  depthwise_conv1d_11 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_23[0][0]']
#  Conv1D)
#
#  activation_24 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_11[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 196, 256)    1024        ['activation_24[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 196, 256)     0           ['batch_normalization_24[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 196, 256)     65792       ['add_12[0][0]']
#
#  activation_25 (Activation)     (None, 196, 256)     0           ['conv1d_13[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 196, 256)    1024        ['activation_25[0][0]']
#  ormalization)
#
#  depthwise_conv1d_12 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_25[0][0]']
#  Conv1D)
#
#  activation_26 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 196, 256)    1024        ['activation_26[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 196, 256)     0           ['batch_normalization_26[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 196, 256)     65792       ['add_13[0][0]']
#
#  activation_27 (Activation)     (None, 196, 256)     0           ['conv1d_14[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 196, 256)    1024        ['activation_27[0][0]']
#  ormalization)
#
#  depthwise_conv1d_13 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_27[0][0]']
#  Conv1D)
#
#  activation_28 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 196, 256)    1024        ['activation_28[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 196, 256)     0           ['batch_normalization_28[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 196, 256)     65792       ['add_14[0][0]']
#
#  activation_29 (Activation)     (None, 196, 256)     0           ['conv1d_15[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 196, 256)    1024        ['activation_29[0][0]']
#  ormalization)
#
#  depthwise_conv1d_14 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_29[0][0]']
#  Conv1D)
#
#  activation_30 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_14[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 196, 256)    1024        ['activation_30[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 196, 256)     0           ['batch_normalization_30[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 196, 256)     65792       ['add_15[0][0]']
#
#  activation_31 (Activation)     (None, 196, 256)     0           ['conv1d_16[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 196, 256)    1024        ['activation_31[0][0]']
#  ormalization)
#
#  depthwise_conv1d_15 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_31[0][0]']
#  Conv1D)
#
#  activation_32 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_15[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 196, 256)    1024        ['activation_32[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 196, 256)     0           ['batch_normalization_32[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 196, 256)     65792       ['add_16[0][0]']
#
#  activation_33 (Activation)     (None, 196, 256)     0           ['conv1d_17[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 196, 256)    1024        ['activation_33[0][0]']
#  ormalization)
#
#  dense_1 (Dense)                (None, 196, 256)     65792       ['batch_normalization_33[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 196, 16, 16)  0           ['dense_1[0][0]']
#
#  tf.compat.v1.transpose (TFOpLa  (None, 16, 196, 16)  0          ['tf.reshape[0][0]']
#  mbda)
#
#  dense_2 (Dense)                (None, 16, 196, 16)  272         ['tf.compat.v1.transpose[0][0]']
#
#  softmax (Softmax)              (None, 16, 196, 16)  0           ['dense_2[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 16, 196, 1)  0           ['softmax[0][0]']
#  )
#
#  tf.__operators__.add (TFOpLamb  (None, 16, 196, 1)  0           ['tf.math.reduce_sum[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 16, 196, 16)  0           ['softmax[0][0]',
#                                                                   'tf.__operators__.add[0][0]']
#
#  dropout (Dropout)              (None, 16, 196, 16)  0           ['tf.math.truediv[0][0]']
#
#  dense_3 (Dense)                (None, 16, 196, 16)  272         ['dropout[0][0]']
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 196, 16, 16)  0          ['dense_3[0][0]']
#  Lambda)
#
#  tf.reshape_1 (TFOpLambda)      (None, 196, 256)     0           ['tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  dense_4 (Dense)                (None, 196, 64)      16448       ['tf.reshape_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 196, 64)      0           ['dense_4[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 196, 64)     128         ['dropout_1[0][0]']
#  rmalization)
#
#  conv1d_18 (Conv1D)             (None, 196, 32)      4128        ['layer_normalization_1[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 196, 64)      6208        ['conv1d_18[0][0]']
#
#  add_17 (Add)                   (None, 196, 64)      0           ['conv1d_19[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['add_17[0][0]']
#  alAveragePooling1D)
#
#  dropout_2 (Dropout)            (None, 64)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_5 (Dense)                (None, 4)            260         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 2,001,284
# Trainable params: 1,983,876
# Non-trainable params: 17,408
# __________________________________________________________________________________________________

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=1e-3, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        tfa.metrics.F1Score(num_classes=4, average='macro', threshold=0.5),
    ],
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=BATCH_SIZE,
    epochs=num_epochs
)
# Out:
# Epoch 1/30
# 90/90 [==============================] - 419s 4s/step - loss: 1.0683 - accuracy: 0.5937 - precision: 0.7629 - recall: 0.4186 - f1_score: 0.5107 - val_loss: 2.7774 - val_accuracy: 0.2288 - val_precision: 0.2288 - val_recall: 0.2288 - val_f1_score: 0.0931
# Epoch 2/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.8236 - accuracy: 0.7532 - precision: 0.8141 - recall: 0.6723 - f1_score: 0.7206 - val_loss: 2.1140 - val_accuracy: 0.2288 - val_precision: 0.2288 - val_recall: 0.2288 - val_f1_score: 0.0931
# Epoch 3/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.7491 - accuracy: 0.7978 - precision: 0.8354 - recall: 0.7400 - f1_score: 0.7741 - val_loss: 2.3728 - val_accuracy: 0.2288 - val_precision: 0.2288 - val_recall: 0.2288 - val_f1_score: 0.0931
# Epoch 4/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.7058 - accuracy: 0.8202 - precision: 0.8579 - recall: 0.7696 - f1_score: 0.8025 - val_loss: 2.1439 - val_accuracy: 0.2288 - val_precision: 0.2288 - val_recall: 0.2288 - val_f1_score: 0.0931
# Epoch 5/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.6550 - accuracy: 0.8458 - precision: 0.8770 - recall: 0.8036 - f1_score: 0.8316 - val_loss: 1.9951 - val_accuracy: 0.3089 - val_precision: 0.3081 - val_recall: 0.3074 - val_f1_score: 0.1176
# Epoch 6/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.6278 - accuracy: 0.8526 - precision: 0.8868 - recall: 0.8202 - f1_score: 0.8461 - val_loss: 2.1172 - val_accuracy: 0.3097 - val_precision: 0.3092 - val_recall: 0.3089 - val_f1_score: 0.1181
# Epoch 7/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.6087 - accuracy: 0.8699 - precision: 0.8922 - recall: 0.8377 - f1_score: 0.8580 - val_loss: 1.0738 - val_accuracy: 0.6308 - val_precision: 0.6933 - val_recall: 0.5568 - val_f1_score: 0.5295
# Epoch 8/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.5793 - accuracy: 0.8817 - precision: 0.9039 - recall: 0.8582 - f1_score: 0.8752 - val_loss: 0.9063 - val_accuracy: 0.7811 - val_precision: 0.8215 - val_recall: 0.7231 - val_f1_score: 0.6987
# Epoch 9/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5853 - accuracy: 0.8825 - precision: 0.9065 - recall: 0.8542 - f1_score: 0.8746 - val_loss: 1.3074 - val_accuracy: 0.6140 - val_precision: 0.6337 - val_recall: 0.5965 - val_f1_score: 0.4907
# Epoch 10/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.5692 - accuracy: 0.8902 - precision: 0.9130 - recall: 0.8654 - f1_score: 0.8838 - val_loss: 0.8541 - val_accuracy: 0.7803 - val_precision: 0.8145 - val_recall: 0.7368 - val_f1_score: 0.7400
# Epoch 11/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5536 - accuracy: 0.8974 - precision: 0.9150 - recall: 0.8750 - f1_score: 0.8903 - val_loss: 0.5902 - val_accuracy: 0.8802 - val_precision: 0.8988 - val_recall: 0.8535 - val_f1_score: 0.8673
# Epoch 12/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.5309 - accuracy: 0.9097 - precision: 0.9272 - recall: 0.8915 - f1_score: 0.9049 - val_loss: 0.9791 - val_accuracy: 0.6842 - val_precision: 0.7096 - val_recall: 0.6636 - val_f1_score: 0.6411
# Epoch 13/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.5455 - accuracy: 0.9058 - precision: 0.9185 - recall: 0.8820 - f1_score: 0.8964 - val_loss: 1.3886 - val_accuracy: 0.5423 - val_precision: 0.5601 - val_recall: 0.5118 - val_f1_score: 0.4487
# Epoch 14/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5335 - accuracy: 0.9065 - precision: 0.9229 - recall: 0.8880 - f1_score: 0.9008 - val_loss: 0.9472 - val_accuracy: 0.7368 - val_precision: 0.7593 - val_recall: 0.7170 - val_f1_score: 0.7061
# Epoch 15/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5236 - accuracy: 0.9119 - precision: 0.9251 - recall: 0.8927 - f1_score: 0.9050 - val_loss: 0.6303 - val_accuracy: 0.8543 - val_precision: 0.8770 - val_recall: 0.8375 - val_f1_score: 0.8432
# Epoch 16/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.5294 - accuracy: 0.9104 - precision: 0.9240 - recall: 0.8964 - f1_score: 0.9065 - val_loss: 0.7360 - val_accuracy: 0.8215 - val_precision: 0.8378 - val_recall: 0.7841 - val_f1_score: 0.7913
# Epoch 17/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5237 - accuracy: 0.9111 - precision: 0.9277 - recall: 0.8962 - f1_score: 0.9083 - val_loss: 0.8178 - val_accuracy: 0.7818 - val_precision: 0.8070 - val_recall: 0.7689 - val_f1_score: 0.7549
# Epoch 18/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5077 - accuracy: 0.9202 - precision: 0.9336 - recall: 0.9063 - f1_score: 0.9162 - val_loss: 1.1470 - val_accuracy: 0.6873 - val_precision: 0.7017 - val_recall: 0.6674 - val_f1_score: 0.6543
# Epoch 19/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5362 - accuracy: 0.9069 - precision: 0.9225 - recall: 0.8901 - f1_score: 0.9029 - val_loss: 0.7659 - val_accuracy: 0.7925 - val_precision: 0.8060 - val_recall: 0.7635 - val_f1_score: 0.7605
# Epoch 20/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5045 - accuracy: 0.9230 - precision: 0.9368 - recall: 0.9105 - f1_score: 0.9205 - val_loss: 0.7071 - val_accuracy: 0.8223 - val_precision: 0.8378 - val_recall: 0.8040 - val_f1_score: 0.7865
# Epoch 21/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.4994 - accuracy: 0.9247 - precision: 0.9373 - recall: 0.9112 - f1_score: 0.9212 - val_loss: 0.6660 - val_accuracy: 0.8528 - val_precision: 0.8652 - val_recall: 0.8375 - val_f1_score: 0.8313
# Epoch 22/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5143 - accuracy: 0.9154 - precision: 0.9284 - recall: 0.9032 - f1_score: 0.9122 - val_loss: 1.0219 - val_accuracy: 0.7140 - val_precision: 0.7384 - val_recall: 0.6804 - val_f1_score: 0.6667
# Epoch 23/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.4990 - accuracy: 0.9258 - precision: 0.9360 - recall: 0.9112 - f1_score: 0.9207 - val_loss: 0.7367 - val_accuracy: 0.8139 - val_precision: 0.8295 - val_recall: 0.7902 - val_f1_score: 0.7846
# Epoch 24/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.5040 - accuracy: 0.9228 - precision: 0.9344 - recall: 0.9097 - f1_score: 0.9184 - val_loss: 0.5241 - val_accuracy: 0.9191 - val_precision: 0.9345 - val_recall: 0.9039 - val_f1_score: 0.9131
# Epoch 25/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.4826 - accuracy: 0.9357 - precision: 0.9437 - recall: 0.9238 - f1_score: 0.9310 - val_loss: 0.7180 - val_accuracy: 0.8101 - val_precision: 0.8304 - val_recall: 0.7918 - val_f1_score: 0.7842
# Epoch 26/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.4972 - accuracy: 0.9279 - precision: 0.9405 - recall: 0.9153 - f1_score: 0.9247 - val_loss: 0.5276 - val_accuracy: 0.9199 - val_precision: 0.9282 - val_recall: 0.9077 - val_f1_score: 0.9132
# Epoch 27/30
# 90/90 [==============================] - 14s 149ms/step - loss: 0.4898 - accuracy: 0.9286 - precision: 0.9390 - recall: 0.9139 - f1_score: 0.9228 - val_loss: 0.6810 - val_accuracy: 0.8330 - val_precision: 0.8593 - val_recall: 0.8063 - val_f1_score: 0.8173
# Epoch 28/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.4875 - accuracy: 0.9314 - precision: 0.9429 - recall: 0.9191 - f1_score: 0.9283 - val_loss: 0.7070 - val_accuracy: 0.8330 - val_precision: 0.8512 - val_recall: 0.8116 - val_f1_score: 0.8057
# Epoch 29/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.4813 - accuracy: 0.9343 - precision: 0.9438 - recall: 0.9210 - f1_score: 0.9298 - val_loss: 0.8257 - val_accuracy: 0.8040 - val_precision: 0.8234 - val_recall: 0.7933 - val_f1_score: 0.7889
# Epoch 30/30
# 90/90 [==============================] - 14s 148ms/step - loss: 0.4801 - accuracy: 0.9356 - precision: 0.9459 - recall: 0.9244 - f1_score: 0.9327 - val_loss: 0.6547 - val_accuracy: 0.8635 - val_precision: 0.8771 - val_recall: 0.8490 - val_f1_score: 0.8515

# %% [markdown]
# # Let's visualize the training progress of the model.

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
#Learning curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([0,1.0])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,5])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
