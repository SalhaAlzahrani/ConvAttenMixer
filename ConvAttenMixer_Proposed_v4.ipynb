# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/ConvAttenMixer/blob/main/ConvAttenMixer_Proposed_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MRI Brain Tumor Classification
# # Proposed Method V4
# Data Augmnetation + MLP

# %%
# !pip install -U tensorflow-addons
# !pip install --upgrade accelerate
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.21.0 typeguard-2.13.3
# Collecting accelerate
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.21.0

# %%
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.optimizers import Adam

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
from google.colab import drive
import tensorflow_addons as tfa
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # Prepare the data

# %%
BATCH_SIZE = 128
IMG_SIZE = (224, 224)
NUM_CLASSES = 4
input_shape = (224, 224, 3)

drive.mount('/content/drive', force_remount=True)
# train data
train_ds = image_dataset_from_directory(
    directory='/content/drive/MyDrive/Brain Tumor MRI/data/Training/',
    #directory='Brain Tumor MRI/data/Training/',
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    shuffle=True,
    seed=1024,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)

# validation data
val_ds = image_dataset_from_directory(
    directory='/content/drive/MyDrive/Brain Tumor MRI/data/Testing/',
    #directory='Brain Tumor MRI/data/Testing/',
    labels='inferred',
    label_mode='categorical',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    color_mode='rgb',
    shuffle=True,
    seed=1024,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Mounted at /content/drive
# Found 5712 files belonging to 4 classes.
# Found 1311 files belonging to 4 classes.

# %%
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])
#Rescale pixel values
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %%
for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# # Hyperparameters

# %%
learning_rate = 0.001
weight_decay = 0.0001
label_smoothing = 0.1

filters=256
depth=8
kernel_size=5
num_epochs = 30
patch_size = 4  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2

#num_transformer_blocks = 8  # Number of repetitions of the transformer layer
print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
# Out:
# Patch size: 4 X 4 = 16
# Patches per image: 3136

# %% [markdown]
# # Patch extraction and embedding : encoding layer

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))

class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %% [markdown]
# # External attention block

# %%
def external_attention(x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %% [markdown]
# # Implement MLP block

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %% [markdown]
# # ConvMixer utilities

# %% [markdown]
# The model used in this experiment is termed as ConvMixer-256/8 where 256 denotes the number of channels and 8 denotes the depth. The resulting model only has 0.8 million parameters.

# %%
def activation_block(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)

def conv_stem(x, filters: int, patch_size: int):
    x = layers.Conv1D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_block(x)

def conv_mixer_block(x, filters: int, kernel_size: int):
    # Depthwise convolution.
    x0 = x
    x = layers.DepthwiseConv1D(kernel_size=kernel_size, padding="same")(x)
    x = layers.Add()([activation_block(x), x0])  # Residual.
    # Pointwise convolution.
    x = layers.Conv1D(filters, kernel_size=1)(x)
    x = activation_block(x)
    return x

def get_conv_mixer_256_8(x):
    """ConvMixer-256/8: https://openreview.net/pdf?id=TVHS5Y4dNvM.
    The hyperparameter values are taken from the paper.
    """
    x = layers.Rescaling(scale=1.0 / 255)(x)
    # Extract patch embeddings.
    x = conv_stem(x, filters, patch_size)
    # ConvMixer blocks.
    for _ in range(depth):
        x = conv_mixer_block(x, filters, kernel_size)
    return x

# %% [markdown]
# # Proposed combined (ConvMixer, SA, EA) model

# %%
def get_model():
    global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)

    ################## STEP 1 : Patch Embedding ##################
    # Extract patches
    x = PatchExtract(patch_size)(x)
    # Create patch embedding
    x = PatchEmbedding(num_patches, embedding_dim)(x)

    ################## STEP 2 : ConvMixer      ##################
    x = get_conv_mixer_256_8(x)

    ################## STEP 3 : Self-attention ##################
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])

     ################## STEP 4 : ConvMixer      ##################
    x = get_conv_mixer_256_8(x)

    ################## STEP 5 : External attention ##################
    x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)

    # Classification block
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    x = layers.GlobalAvgPool1D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 224, 224, 3)  0           ['input_2[0][0]']
#
#  patch_extract_1 (PatchExtract)  (None, 3136, 48)    0           ['sequential[1][0]']
#
#  patch_embedding_1 (PatchEmbedd  (None, 3136, 64)    203840      ['patch_extract_1[0][0]']
#  ing)
#
#  rescaling_3 (Rescaling)        (None, 3136, 64)     0           ['patch_embedding_1[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 784, 256)     65792       ['rescaling_3[0][0]']
#
#  activation_34 (Activation)     (None, 784, 256)     0           ['conv1d_18[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 784, 256)    1024        ['activation_34[0][0]']
#  ormalization)
#
#  depthwise_conv1d_16 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_34[0][0]']
#  Conv1D)
#
#  activation_35 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_16[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 784, 256)    1024        ['activation_35[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 784, 256)     0           ['batch_normalization_35[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 784, 256)     65792       ['add_17[0][0]']
#
#  activation_36 (Activation)     (None, 784, 256)     0           ['conv1d_19[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 784, 256)    1024        ['activation_36[0][0]']
#  ormalization)
#
#  depthwise_conv1d_17 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_36[0][0]']
#  Conv1D)
#
#  activation_37 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_17[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 784, 256)    1024        ['activation_37[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 784, 256)     0           ['batch_normalization_37[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 784, 256)     65792       ['add_18[0][0]']
#
#  activation_38 (Activation)     (None, 784, 256)     0           ['conv1d_20[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 784, 256)    1024        ['activation_38[0][0]']
#  ormalization)
#
#  depthwise_conv1d_18 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_38[0][0]']
#  Conv1D)
#
#  activation_39 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_18[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 784, 256)    1024        ['activation_39[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 784, 256)     0           ['batch_normalization_39[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 784, 256)     65792       ['add_19[0][0]']
#
#  activation_40 (Activation)     (None, 784, 256)     0           ['conv1d_21[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 784, 256)    1024        ['activation_40[0][0]']
#  ormalization)
#
#  depthwise_conv1d_19 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_40[0][0]']
#  Conv1D)
#
#  activation_41 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_19[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 784, 256)    1024        ['activation_41[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 784, 256)     0           ['batch_normalization_41[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 784, 256)     65792       ['add_20[0][0]']
#
#  activation_42 (Activation)     (None, 784, 256)     0           ['conv1d_22[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 784, 256)    1024        ['activation_42[0][0]']
#  ormalization)
#
#  depthwise_conv1d_20 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_42[0][0]']
#  Conv1D)
#
#  activation_43 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_20[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 784, 256)    1024        ['activation_43[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 784, 256)     0           ['batch_normalization_43[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 784, 256)     65792       ['add_21[0][0]']
#
#  activation_44 (Activation)     (None, 784, 256)     0           ['conv1d_23[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 784, 256)    1024        ['activation_44[0][0]']
#  ormalization)
#
#  depthwise_conv1d_21 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_44[0][0]']
#  Conv1D)
#
#  activation_45 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_21[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 784, 256)    1024        ['activation_45[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 784, 256)     0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 784, 256)     65792       ['add_22[0][0]']
#
#  activation_46 (Activation)     (None, 784, 256)     0           ['conv1d_24[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 784, 256)    1024        ['activation_46[0][0]']
#  ormalization)
#
#  depthwise_conv1d_22 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_46[0][0]']
#  Conv1D)
#
#  activation_47 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_22[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 784, 256)    1024        ['activation_47[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 784, 256)     0           ['batch_normalization_47[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 784, 256)     65792       ['add_23[0][0]']
#
#  activation_48 (Activation)     (None, 784, 256)     0           ['conv1d_25[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 784, 256)    1024        ['activation_48[0][0]']
#  ormalization)
#
#  depthwise_conv1d_23 (Depthwise  (None, 784, 256)    1536        ['batch_normalization_48[0][0]']
#  Conv1D)
#
#  activation_49 (Activation)     (None, 784, 256)     0           ['depthwise_conv1d_23[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 784, 256)    1024        ['activation_49[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 784, 256)     0           ['batch_normalization_49[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 784, 256)     65792       ['add_24[0][0]']
#
#  activation_50 (Activation)     (None, 784, 256)     0           ['conv1d_26[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 784, 256)    1024        ['activation_50[0][0]']
#  ormalization)
#
#  layer_normalization_2 (LayerNo  (None, 784, 256)    512         ['batch_normalization_50[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 784, 256)    263168      ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_25 (Add)                   (None, 784, 256)     0           ['multi_head_attention_1[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  rescaling_4 (Rescaling)        (None, 784, 256)     0           ['add_25[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 196, 256)     262400      ['rescaling_4[0][0]']
#
#  activation_51 (Activation)     (None, 196, 256)     0           ['conv1d_27[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 196, 256)    1024        ['activation_51[0][0]']
#  ormalization)
#
#  depthwise_conv1d_24 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_51[0][0]']
#  Conv1D)
#
#  activation_52 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_24[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 196, 256)    1024        ['activation_52[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 196, 256)     0           ['batch_normalization_52[0][0]',
#                                                                   'batch_normalization_51[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 196, 256)     65792       ['add_26[0][0]']
#
#  activation_53 (Activation)     (None, 196, 256)     0           ['conv1d_28[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 196, 256)    1024        ['activation_53[0][0]']
#  ormalization)
#
#  depthwise_conv1d_25 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_53[0][0]']
#  Conv1D)
#
#  activation_54 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_25[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 196, 256)    1024        ['activation_54[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 196, 256)     0           ['batch_normalization_54[0][0]',
#                                                                   'batch_normalization_53[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 196, 256)     65792       ['add_27[0][0]']
#
#  activation_55 (Activation)     (None, 196, 256)     0           ['conv1d_29[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 196, 256)    1024        ['activation_55[0][0]']
#  ormalization)
#
#  depthwise_conv1d_26 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_55[0][0]']
#  Conv1D)
#
#  activation_56 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_26[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 196, 256)    1024        ['activation_56[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 196, 256)     0           ['batch_normalization_56[0][0]',
#                                                                   'batch_normalization_55[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 196, 256)     65792       ['add_28[0][0]']
#
#  activation_57 (Activation)     (None, 196, 256)     0           ['conv1d_30[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 196, 256)    1024        ['activation_57[0][0]']
#  ormalization)
#
#  depthwise_conv1d_27 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_57[0][0]']
#  Conv1D)
#
#  activation_58 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_27[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 196, 256)    1024        ['activation_58[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 196, 256)     0           ['batch_normalization_58[0][0]',
#                                                                   'batch_normalization_57[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 196, 256)     65792       ['add_29[0][0]']
#
#  activation_59 (Activation)     (None, 196, 256)     0           ['conv1d_31[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 196, 256)    1024        ['activation_59[0][0]']
#  ormalization)
#
#  depthwise_conv1d_28 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_59[0][0]']
#  Conv1D)
#
#  activation_60 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_28[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 196, 256)    1024        ['activation_60[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 196, 256)     0           ['batch_normalization_60[0][0]',
#                                                                   'batch_normalization_59[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 196, 256)     65792       ['add_30[0][0]']
#
#  activation_61 (Activation)     (None, 196, 256)     0           ['conv1d_32[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 196, 256)    1024        ['activation_61[0][0]']
#  ormalization)
#
#  depthwise_conv1d_29 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_61[0][0]']
#  Conv1D)
#
#  activation_62 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_29[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 196, 256)    1024        ['activation_62[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 196, 256)     0           ['batch_normalization_62[0][0]',
#                                                                   'batch_normalization_61[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 196, 256)     65792       ['add_31[0][0]']
#
#  activation_63 (Activation)     (None, 196, 256)     0           ['conv1d_33[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 196, 256)    1024        ['activation_63[0][0]']
#  ormalization)
#
#  depthwise_conv1d_30 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_63[0][0]']
#  Conv1D)
#
#  activation_64 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_30[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 196, 256)    1024        ['activation_64[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 196, 256)     0           ['batch_normalization_64[0][0]',
#                                                                   'batch_normalization_63[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 196, 256)     65792       ['add_32[0][0]']
#
#  activation_65 (Activation)     (None, 196, 256)     0           ['conv1d_34[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 196, 256)    1024        ['activation_65[0][0]']
#  ormalization)
#
#  depthwise_conv1d_31 (Depthwise  (None, 196, 256)    1536        ['batch_normalization_65[0][0]']
#  Conv1D)
#
#  activation_66 (Activation)     (None, 196, 256)     0           ['depthwise_conv1d_31[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 196, 256)    1024        ['activation_66[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 196, 256)     0           ['batch_normalization_66[0][0]',
#                                                                   'batch_normalization_65[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 196, 256)     65792       ['add_33[0][0]']
#
#  activation_67 (Activation)     (None, 196, 256)     0           ['conv1d_35[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 196, 256)    1024        ['activation_67[0][0]']
#  ormalization)
#
#  dense_6 (Dense)                (None, 196, 256)     65792       ['batch_normalization_67[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 196, 16, 16)  0           ['dense_6[0][0]']
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 16, 196, 16)  0          ['tf.reshape_2[0][0]']
#  Lambda)
#
#  dense_7 (Dense)                (None, 16, 196, 16)  272         ['tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  softmax_1 (Softmax)            (None, 16, 196, 16)  0           ['dense_7[0][0]']
#
#  tf.math.reduce_sum_1 (TFOpLamb  (None, 16, 196, 1)  0           ['softmax_1[0][0]']
#  da)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 16, 196, 1)  0           ['tf.math.reduce_sum_1[0][0]']
#  mbda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 16, 196, 16)  0          ['softmax_1[0][0]',
#                                                                   'tf.__operators__.add_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 196, 16)  0           ['tf.math.truediv_1[0][0]']
#
#  dense_8 (Dense)                (None, 16, 196, 16)  272         ['dropout_2[0][0]']
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 196, 16, 16)  0          ['dense_8[0][0]']
#  Lambda)
#
#  tf.reshape_3 (TFOpLambda)      (None, 196, 256)     0           ['tf.compat.v1.transpose_3[0][0]'
#                                                                  ]
#
#  dense_9 (Dense)                (None, 196, 64)      16448       ['tf.reshape_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 196, 64)      0           ['dense_9[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 196, 64)     128         ['dropout_3[0][0]']
#  rmalization)
#
#  dense_10 (Dense)               (None, 196, 64)      4160        ['layer_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 196, 64)      0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 196, 64)      4160        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 196, 64)      0           ['dense_11[0][0]']
#
#  add_34 (Add)                   (None, 196, 64)      0           ['dropout_5[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['add_34[0][0]']
#  alAveragePooling1D)
#
#  dropout_6 (Dropout)            (None, 64)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_12 (Dense)               (None, 4)            260         ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 1,999,268
# Trainable params: 1,981,860
# Non-trainable params: 17,408
# __________________________________________________________________________________________________

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=learning_rate, weight_decay=weight_decay)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=1e-3, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        tf.keras.metrics.Precision(),
        tf.keras.metrics.Recall(),
        tfa.metrics.F1Score(num_classes=4, average='macro', threshold=0.5),
    ],
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=BATCH_SIZE,
    epochs=num_epochs
)
# Out:
# Epoch 1/30
# 45/45 [==============================] - 384s 6s/step - loss: 1.0864 - accuracy: 0.5814 - precision_1: 0.8003 - recall_1: 0.3473 - f1_score: 0.4384 - val_loss: 2.7576 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 2/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.8175 - accuracy: 0.7572 - precision_1: 0.8156 - recall_1: 0.6805 - f1_score: 0.7236 - val_loss: 2.7043 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 3/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.7302 - accuracy: 0.8074 - precision_1: 0.8425 - recall_1: 0.7565 - f1_score: 0.7851 - val_loss: 3.3657 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 4/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.6812 - accuracy: 0.8283 - precision_1: 0.8585 - recall_1: 0.7880 - f1_score: 0.8134 - val_loss: 3.1803 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 5/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.6764 - accuracy: 0.8290 - precision_1: 0.8608 - recall_1: 0.7911 - f1_score: 0.8160 - val_loss: 3.4922 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 6/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.6273 - accuracy: 0.8578 - precision_1: 0.8851 - recall_1: 0.8295 - f1_score: 0.8499 - val_loss: 3.3091 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 7/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.6155 - accuracy: 0.8575 - precision_1: 0.8843 - recall_1: 0.8246 - f1_score: 0.8464 - val_loss: 3.8405 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 8/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5750 - accuracy: 0.8860 - precision_1: 0.9059 - recall_1: 0.8643 - f1_score: 0.8798 - val_loss: 3.4042 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 9/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5620 - accuracy: 0.8939 - precision_1: 0.9117 - recall_1: 0.8710 - f1_score: 0.8860 - val_loss: 3.6112 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 10/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5651 - accuracy: 0.8937 - precision_1: 0.9145 - recall_1: 0.8725 - f1_score: 0.8890 - val_loss: 3.4307 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 11/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5446 - accuracy: 0.8999 - precision_1: 0.9146 - recall_1: 0.8829 - f1_score: 0.8942 - val_loss: 3.4522 - val_accuracy: 0.2288 - val_precision_1: 0.2288 - val_recall_1: 0.2288 - val_f1_score: 0.0931
# Epoch 12/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5456 - accuracy: 0.9035 - precision_1: 0.9199 - recall_1: 0.8831 - f1_score: 0.8977 - val_loss: 2.7401 - val_accuracy: 0.2296 - val_precision_1: 0.2290 - val_recall_1: 0.2288 - val_f1_score: 0.0932
# Epoch 13/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.5365 - accuracy: 0.9037 - precision_1: 0.9198 - recall_1: 0.8874 - f1_score: 0.8990 - val_loss: 2.4201 - val_accuracy: 0.3272 - val_precision_1: 0.3243 - val_recall_1: 0.3181 - val_f1_score: 0.2115
# Epoch 14/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.5194 - accuracy: 0.9140 - precision_1: 0.9279 - recall_1: 0.8971 - f1_score: 0.9084 - val_loss: 1.6933 - val_accuracy: 0.4592 - val_precision_1: 0.4620 - val_recall_1: 0.4500 - val_f1_score: 0.3123
# Epoch 15/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5282 - accuracy: 0.9088 - precision_1: 0.9231 - recall_1: 0.8913 - f1_score: 0.9031 - val_loss: 1.1701 - val_accuracy: 0.6606 - val_precision_1: 0.6824 - val_recall_1: 0.6293 - val_f1_score: 0.5649
# Epoch 16/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5036 - accuracy: 0.9226 - precision_1: 0.9356 - recall_1: 0.9079 - f1_score: 0.9183 - val_loss: 1.3143 - val_accuracy: 0.5957 - val_precision_1: 0.6177 - val_recall_1: 0.5744 - val_f1_score: 0.4823
# Epoch 17/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4984 - accuracy: 0.9286 - precision_1: 0.9400 - recall_1: 0.9130 - f1_score: 0.9237 - val_loss: 1.0109 - val_accuracy: 0.7140 - val_precision_1: 0.7249 - val_recall_1: 0.7056 - val_f1_score: 0.6678
# Epoch 18/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4923 - accuracy: 0.9308 - precision_1: 0.9408 - recall_1: 0.9207 - f1_score: 0.9278 - val_loss: 0.6048 - val_accuracy: 0.8848 - val_precision_1: 0.8983 - val_recall_1: 0.8696 - val_f1_score: 0.8702
# Epoch 19/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.5003 - accuracy: 0.9221 - precision_1: 0.9346 - recall_1: 0.9084 - f1_score: 0.9182 - val_loss: 0.6516 - val_accuracy: 0.8612 - val_precision_1: 0.8802 - val_recall_1: 0.8459 - val_f1_score: 0.8482
# Epoch 20/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4871 - accuracy: 0.9300 - precision_1: 0.9409 - recall_1: 0.9195 - f1_score: 0.9268 - val_loss: 0.5945 - val_accuracy: 0.8879 - val_precision_1: 0.8960 - val_recall_1: 0.8741 - val_f1_score: 0.8716
# Epoch 21/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4966 - accuracy: 0.9291 - precision_1: 0.9382 - recall_1: 0.9163 - f1_score: 0.9237 - val_loss: 0.8350 - val_accuracy: 0.8024 - val_precision_1: 0.8092 - val_recall_1: 0.7895 - val_f1_score: 0.7639
# Epoch 22/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4845 - accuracy: 0.9314 - precision_1: 0.9430 - recall_1: 0.9179 - f1_score: 0.9274 - val_loss: 0.6068 - val_accuracy: 0.8764 - val_precision_1: 0.8820 - val_recall_1: 0.8665 - val_f1_score: 0.8663
# Epoch 23/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4795 - accuracy: 0.9345 - precision_1: 0.9441 - recall_1: 0.9259 - f1_score: 0.9325 - val_loss: 0.6039 - val_accuracy: 0.8780 - val_precision_1: 0.8839 - val_recall_1: 0.8650 - val_f1_score: 0.8627
# Epoch 24/30
# 45/45 [==============================] - 13s 281ms/step - loss: 0.4631 - accuracy: 0.9436 - precision_1: 0.9524 - recall_1: 0.9324 - f1_score: 0.9403 - val_loss: 0.7134 - val_accuracy: 0.8406 - val_precision_1: 0.8474 - val_recall_1: 0.8299 - val_f1_score: 0.8262
# Epoch 25/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4690 - accuracy: 0.9426 - precision_1: 0.9503 - recall_1: 0.9310 - f1_score: 0.9379 - val_loss: 0.7822 - val_accuracy: 0.8063 - val_precision_1: 0.8116 - val_recall_1: 0.8017 - val_f1_score: 0.7999
# Epoch 26/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4759 - accuracy: 0.9375 - precision_1: 0.9479 - recall_1: 0.9275 - f1_score: 0.9351 - val_loss: 0.6236 - val_accuracy: 0.8810 - val_precision_1: 0.9012 - val_recall_1: 0.8627 - val_f1_score: 0.8703
# Epoch 27/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4706 - accuracy: 0.9405 - precision_1: 0.9493 - recall_1: 0.9280 - f1_score: 0.9362 - val_loss: 0.5522 - val_accuracy: 0.8993 - val_precision_1: 0.9054 - val_recall_1: 0.8902 - val_f1_score: 0.8905
# Epoch 28/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4623 - accuracy: 0.9433 - precision_1: 0.9513 - recall_1: 0.9326 - f1_score: 0.9393 - val_loss: 0.5669 - val_accuracy: 0.9016 - val_precision_1: 0.9090 - val_recall_1: 0.8917 - val_f1_score: 0.8960
# Epoch 29/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4715 - accuracy: 0.9380 - precision_1: 0.9466 - recall_1: 0.9277 - f1_score: 0.9346 - val_loss: 0.5495 - val_accuracy: 0.8955 - val_precision_1: 0.9048 - val_recall_1: 0.8917 - val_f1_score: 0.8943
# Epoch 30/30
# 45/45 [==============================] - 13s 280ms/step - loss: 0.4662 - accuracy: 0.9410 - precision_1: 0.9513 - recall_1: 0.9305 - f1_score: 0.9385 - val_loss: 0.6376 - val_accuracy: 0.8749 - val_precision_1: 0.8874 - val_recall_1: 0.8719 - val_f1_score: 0.8767

# %% [markdown]
# # Let's visualize the training progress of the model.

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
#Learning curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([0,1.0])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,5])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
